# %%
print("HOPE AI")
# Out:
# HOPE AI

# %%
input("Enter your institute name?:")
# Out:
# Enter your institute name?:HOPE AI
# 'HOPE AI'

# %%
input("Enter your name:")
int(input("Enter your age:"))
input("Enter your school name:")
input("Enter your dergree:")
# Out:
# Enter your name:Dhanushya
# Enter your age:22
# Enter your school name:RMKCET
# Enter your dergree:B.E ECE
# 'B.E ECE'

# %%
#Addition
a=int(input("a="))
b=int(input("b="))
print("add=",a+b)
# Out:
# a=43
# b=34
# add= 77

# %%
#Subtraction
a=int(input("a="))
b=int(input("b="))
print("Sub=",a-b)
# Out:
# a=43
# b=34
# Sub= 9

# %%
#Multiplication
a=int(input("a="))
b=int(input("b="))
print("Mul=",a*b)
# Out:
# a=63
# b=97
# Mul= 6111

# %%
#Division
a=float(input("a="))
b=float(input("b="))
print("Div",a/b)
# Out:
# a=76
# b=31
# Div 2.4516129032258065

# %%
#Floor Division
a=float(input("a="))
b=float(input("b="))
print("Float Div",a//b)
# Out:
# a=76
# b=31
# Float Div 2.0

# %%
#Modulo
a=float(input("a="))
b=float(input("b="))
print("Modulo",a%b)
# Out:
# a=76
# b=31
# Modulo 14.0

# %%
#power
a=int(input("a="))
b=int(input("b="))
print("Power",a**b)
# Out:
# a=4
# b=4
# Power 256
